# %% [markdown]
# ## Aufgabe 1
#
# Trenngerade: y=-2x-1
#
# y>=-2x-1 für +1 Klassifikation
#
# Die Perzeptrons 1-3 sind alle gleich. Nummer 4 besitzt die selbe Trenngerade aber die Klassifikationen sind vertauscht, da mit -1 multipliziert wird.

# %%
# Aufgabe 2
p  = (2,1,1)
v = (1,1)

def ExecutePerceptron(perceptron, values):
    result = 0
    for i in range(len(perceptron)):
        w = perceptron[i]
        if i == len(perceptron)-1:
            result += w
        else:
            result += w * values[i]
    return result

ExecutePerceptron(p,v)
# Out:
# 4

# %%
#AND
pAnd = (2, 2, -3)

#OR
pOr = (2, 2, -1)

#Komplement
pKomp = () #?

# %% [markdown]
# ### XOR
# XOR kann nicht implementiert werden, da im Perceptron nur eine einzelne Trenngerade gibt, gäbe es 2 Trenngeraden könnte man es daarstellen.

# %%
#Aufgabe 3
import random

#Datensatz
dataset = [(False, (random.uniform(-1,1),random.uniform(-1,1))) for _ in range(10)]

#Gerade
g = (random.uniform(-1,1),random.uniform(-1,1),random.uniform(-1,1))

for i in range(len(dataset)):
    print(dataset[i])
    if ExecutePerceptron(g, dataset[i][1]) > 0:
        dataset[i] = (True, dataset[i][1])
dataset
# Out:
# (False, (0.23438575314808774, 0.6416328385677943))
# (False, (0.9426501920300905, -0.9354085224546047))
# (False, (-0.6439414572832616, 0.3188799689513018))
# (False, (-0.2064333665697078, -0.39010853572523496))
# (False, (-0.7684132468236378, -0.26045101495386835))
# (False, (-0.3691201542944875, -0.5709696144490974))
# (False, (0.964969547979843, 0.605275738755964))
# (False, (-0.6118225360722742, 0.3348615805199924))
# (False, (-0.18395077851976382, -0.8406190886945653))
# (False, (-0.9305427296792219, 0.6726281295576575))
# [(True, (0.23438575314808774, 0.6416328385677943)),
#  (True, (0.9426501920300905, -0.9354085224546047)),
#  (True, (-0.6439414572832616, 0.3188799689513018)),
#  (True, (-0.2064333665697078, -0.39010853572523496)),
#  (False, (-0.7684132468236378, -0.26045101495386835)),
#  (True, (-0.3691201542944875, -0.5709696144490974)),
#  (True, (0.964969547979843, 0.605275738755964)),
#  (True, (-0.6118225360722742, 0.3348615805199924)),
#  (True, (-0.18395077851976382, -0.8406190886945653)),
#  (True, (-0.9305427296792219, 0.6726281295576575))]

# %%
def TrainPerceptron(perceptron, dataset, maxIterations, learningRate):
    for _ in range(maxIterations):
        misclassified = []
        for d in dataset:
            res = True
            if ExecutePerceptron(perceptron, d[1]) < 0: res = False
            if res != d[0]:
                misclassified.append(d)
        print(f"misclassified: {len(misclassified)}, iteration:{_}")
        if len(misclassified) == 0:
            return perceptron
        
        r = random.choice(misclassified)
        pred = ExecutePerceptron(perceptron, r[1])
        error = r[0] - pred
        percList = list(perceptron)
        for i in range(len(r[1])):
            percList[i] += learningRate * error * r[1][i]
        percList[-1] += learningRate * error
        perceptron = tuple(percList)
    return perceptron

print(g)
p = (random.uniform(-1,1),random.uniform(-1,1),random.uniform(-1,1))
print(p)
print(TrainPerceptron(p,dataset,100,0.01))
# Out:
# (0.8233153450382449, 0.39639943271128075, 0.537537920932545)
